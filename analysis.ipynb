# %%
from pickle import load

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
was_upset = {
    "Alabama": 1,
    "Texas A&M-Corpus Christi": 0,
    "Maryland": 0,
    "West Virginia": 0,
    "San Diego State": 0,
    "College of Charleston": 0,
    "Virginia": 1,
    "Furman": 0,
    "Creighton": 0,
    "NC State": 0,
    "Baylor": 1,
    "UC Santa Barbara": 0,
    "Missouri": 1,
    "Utah State": 0,
    "Arizona": 1,
    "Princeton": 0,
    "Purdue": 1,
    "Fairleigh Dickinson": 0,
    "Memphis": 1,
    "Florida Atlantic": 0,
    "Duke": 0,
    "Oral Roberts": 0,
    "Tennessee": 1,
    "Louisiana": 0,
    "Kentucky": 0,
    "Providence": 0,
    "Kansas State": 1,
    "Montana State": 0,
    "Michigan State": 0,
    "Southern California": 0,
    "Marquette": 1,
    "Vermont": 0,
    "Houston": 1,
    "Northern Kentucky": 0,
    "Auburn": 0,
    "Iowa": 1,
    "Miami (FL)": 0,
    "Drake": 0,
    "Indiana": 1,
    "Kent State": 0,
    "Xavier": 0,
    "Kennesaw State": 0,
    "Pittsburgh": 0,
    "Iowa State": 1,
    "Texas": 1,
    "Colgate": 0,
    "Penn State": 0,
    "Texas A&M": 1,
    "Kansas": 1,
    "Howard": 0,
    "Arkansas": 0,
    "Illinois": 0,
    "Saint Mary's (CA)": 0,
    "Virginia Commonwealth": 0,
    "Connecticut": 0,
    "Iona": 0,
    "TCU": 0,
    "Gonzaga": 1,
    "Grand Canyon": 0,
    "Northwestern": 0,
    "Boise State": 0,
    "UCLA": 1,
    "UNC Asheville": 0,
    "Texas Southern": 0,
    "FDU": 0,
    "SE Missouri State": 0,
    "Mississippi State": 0,
    "Arizona State": 0,
    "Nevada": 0
}
updf = pd.DataFrame(was_upset, index=["performance"])
updf

did_upset = {
    "Alabama": 0,
    "Texas A&M-Corpus Christi": 0,
    "Maryland": 0,
    "West Virginia": 0,
    "San Diego State": 1,
    "College of Charleston": 0,
    "Virginia": 0,
    "Furman": 1,
    "Creighton": 1,
    "NC State": 0,
    "Baylor": 0,
    "UC Santa Barbara": 0,
    "Missouri": 0,
    "Utah State": 0,
    "Arizona": 0,
    "Princeton": 2,
    "Purdue": 0,
    "Fairleigh Dickinson": 1,
    "Memphis": 0,
    "Florida Atlantic": 3,
    "Duke": 0,
    "Oral Roberts": 0,
    "Tennessee": 0,
    "Louisiana": 0,
    "Kentucky": 0,
    "Providence": 0,
    "Kansas State": 0,
    "Montana State": 0,
    "Michigan State": 1,
    "Southern California": 0,
    "Marquette": 0,
    "Vermont": 0,
    "Houston": 0,
    "Northern Kentucky": 0,
    "Auburn": 1,
    "Iowa": 0,
    "Miami (FL)": 3,
    "Drake": 0,
    "Indiana": 0,
    "Kent State": 0,
    "Xavier": 0,
    "Kennesaw State": 0,
    "Pittsburgh": 1,
    "Iowa State": 0,
    "Texas": 0,
    "Colgate": 0,
    "Penn State": 1,
    "Texas A&M": 0,
    "Kansas": 0,
    "Howard": 0,
    "Arkansas": 1,
    "Illinois": 0,
    "Saint Mary's (CA)": 0,
    "Virginia Commonwealth": 0,
    "Connecticut": 1,
    "Iona": 0,
    "TCU": 0,
    "Gonzaga": 1,
    "Grand Canyon": 0,
    "Northwestern": 0,
    "Boise State": 0,
    "UCLA": 0,
    "UNC Asheville": 0,
    "Texas Southern": 0,
    "FDU": 1,
    "SE Missouri State": 0,
    "Mississippi State": 0,
    "Arizona State": 0,
    "Nevada": 0
}
dpdf = pd.DataFrame(did_upset, index=["performance"])
dpdf

performance = {
    "Alabama": 3,
    "Texas A&M-Corpus Christi": 1,
    "Maryland": 2,
    "West Virginia": 1,
    "San Diego State": 6,
    "College of Charleston": 1,
    "Virginia": 1,
    "Furman": 2,
    "Creighton": 4,
    "NC State": 1,
    "Baylor": 2,
    "UC Santa Barbara": 1,
    "Missouri": 2,
    "Utah State": 1,
    "Arizona": 1,
    "Princeton": 3,
    "Purdue": 1,
    "Fairleigh Dickinson": 2,
    "Memphis": 1,
    "Florida Atlantic": 5,
    "Duke": 2,
    "Oral Roberts": 1,
    "Tennessee": 3,
    "Louisiana": 1,
    "Kentucky": 2,
    "Providence": 1,
    "Kansas State": 4,
    "Montana State": 1,
    "Michigan State": 3,
    "Southern California": 1,
    "Marquette": 2,
    "Vermont": 1,
    "Houston": 3,
    "Northern Kentucky": 1,
    "Auburn": 2,
    "Iowa": 1,
    "Miami (FL)": 5,
    "Drake": 1,
    "Indiana": 2,
    "Kent State": 1,
    "Xavier": 3,
    "Kennesaw State": 1,
    "Pittsburgh": 2,
    "Iowa State": 1,
    "Texas": 4,
    "Colgate": 1,
    "Penn State": 2,
    "Texas A&M": 1,
    "Kansas": 2,
    "Howard": 1,
    "Arkansas": 3,
    "Illinois": 1,
    "Saint Mary's (CA)": 2,
    "Virginia Commonwealth": 1,
    "Connecticut": 7,
    "Iona": 1,
    "TCU": 2,
    "Gonzaga": 4,
    "Grand Canyon": 1,
    "Northwestern": 2,
    "Boise State": 1,
    "UCLA": 3,
    "UNC Asheville": 1,
    "Texas Southern": 0,
    "FDU": 2,
    "SE Missouri State": 0,
    "Mississippi State": 0,
    "Arizona State": 1,
    "Nevada": 0
}
pfdf = pd.DataFrame(performance, index=["performance"])
pfdf
# Out:
#              Alabama  Texas A&M-Corpus Christi  Maryland  West Virginia  \
# performance        3                         1         2              1
#
#              San Diego State  College of Charleston  Virginia  Furman  \
# performance                6                      1         1       2
#
#              Creighton  NC State  ...  Northwestern  Boise State  UCLA  \
# performance          4         1  ...             2            1     3
#
#              UNC Asheville  Texas Southern  FDU  SE Missouri State  \
# performance              1               0    2                  0
#
#              Mississippi State  Arizona State  Nevada
# performance                  0              1       0
#
# [1 rows x 69 columns]

# %%
with open("./seeding_optim.pkl", "rb") as doc:
    optim_x = load(doc)

with open("./seeding_sample.pkl", "rb") as doc:
    samp_x = load(doc)

# %%
print(optim_x[-1])
# Out:
# (1) Houston
# (1) Kansas
# (1) Purdue
# (1) Texas
# (2) Florida Atlantic
# (2) Alabama
# (2) Oral Roberts
# (2) Saint Mary's (CA)
# (3) Illinois
# (3) UCLA
# (3) College of Charleston
# (3) Kent State
# (4) Duke
# (4) NC State
# (4) Kentucky
# (4) Kennesaw State
# (5) San Diego State
# (5) Texas Southern
# (5) Southern California
# (5) Gonzaga
# (6) Auburn
# (6) Utah State
# (6) Kansas State
# (6) Arizona
# (7) Arkansas
# (7) Boise State
# (7) Baylor
# (7) Memphis
# (8) Connecticut
# (8) Iowa
# (8) Creighton
# (8) Providence
# (9) Colgate
# (9) Iowa State
# (9) Louisiana
# (9) Xavier
# (10) Texas A&M
# (10) Virginia
# (10) Texas A&M-Corpus Christi
# (10) Miami (FL)
# (11) Northwestern
# (11) Maryland
# (11) Missouri
# (11) TCU
# (12) Mississippi State
# (12) Drake
# (12) Grand Canyon
# (12) Marquette
# (13) Iona
# (13) West Virginia
# (13) Vermont
# (13) Nevada
# (14) Princeton
# (14) Howard
# (14) Virginia Commonwealth
# (14) Tennessee
# (15) Michigan State
# (15) Penn State
# ...

# %%
d = {}
for _x in samp_x:
    if _x._score not in d:
        d[_x._score] = [_x]
    else:
        d[_x._score].append(_x)
del d[None]
print(max(d.keys()))
#print(d[max(d.keys())])
print(d[max(d.keys())][0])
#print(d[max(d.keys())][0].mlb)
# Out:
# -142.6
# (1) Oral Roberts
# (1) Texas
# (1) Kansas
# (1) Houston
# (2) Arizona
# (2) Montana State
# (2) Gonzaga
# (2) Auburn
# (3) Connecticut
# (3) Purdue
# (3) San Diego State
# (3) NC State
# (4) Michigan State
# (4) Baylor
# (4) Nevada
# (4) Drake
# (5) College of Charleston
# (5) Maryland
# (5) Tennessee
# (5) Arkansas
# (6) Iona
# (6) Virginia Commonwealth
# (6) Kentucky
# (6) Southern California
# (7) Creighton
# (7) UNC Asheville
# (7) Northern Kentucky
# (7) TCU
# (8) Iowa
# (8) Missouri
# (8) Virginia
# (8) UC Santa Barbara
# (9) Kansas State
# (9) Xavier
# (9) Memphis
# (9) UCLA
# (10) Kent State
# (10) Mississippi State
# (10) Marquette
# (10) Texas Southern
# (11) Texas A&M-Corpus Christi
# (11) Northwestern
# (11) Saint Mary's (CA)
# (11) Howard
# (12) Indiana
# (12) Illinois
# (12) Grand Canyon
# (12) Duke
# (13) Utah State
# (13) Florida Atlantic
# (13) Alabama
# (13) Vermont
# (14) Louisiana
# (14) Princeton
# (14) Kennesaw State
# (14) Miami (FL)
# (15) Iowa State
# ...

# %%
seed_by_team = {k.id: [] for k in sorted(samp_x[0].teams, key=lambda x: x.seed)}
for samp in samp_x:
    for n, t in enumerate(samp.teams):
        seed_by_team[t.id].append(n)

# %%
df = pd.DataFrame.from_dict(seed_by_team)
variances = pd.DataFrame(df.var())
skews = pd.DataFrame(df.skew())
covariances = df.cov() * -(1 - np.identity(64))

# %%
variances.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f26fb_row0_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_f26fb_row1_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_f26fb_row2_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_f26fb_row3_col0, #T_f26fb_row40_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_f26fb_row4_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f26fb_row5_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_f26fb_row6_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_f26fb_row7_col0, #T_f26fb_row53_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_f26fb_row8_col0, #T_f26fb_row15_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_f26fb_row9_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_f26fb_row10_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_f26fb_row11_col0 {
# ...

# %%
covariances.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fa343_row0_col0, #T_fa343_row6_col18, #T_fa343_row12_col60, #T_fa343_row13_col38, #T_fa343_row13_col59, #T_fa343_row15_col62, #T_fa343_row18_col28, #T_fa343_row24_col43, #T_fa343_row25_col21, #T_fa343_row25_col62, #T_fa343_row39_col4, #T_fa343_row42_col0, #T_fa343_row44_col5, #T_fa343_row46_col46, #T_fa343_row48_col43, #T_fa343_row51_col12, #T_fa343_row51_col22, #T_fa343_row54_col50, #T_fa343_row58_col19, #T_fa343_row62_col30 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_fa343_row0_col1, #T_fa343_row0_col39, #T_fa343_row28_col43, #T_fa343_row35_col13, #T_fa343_row35_col23, #T_fa343_row38_col27, #T_fa343_row44_col32, #T_fa343_row50_col24, #T_fa343_row52_col2, #T_fa343_row57_col12 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# ...

# %%
skews.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_def19_row0_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_def19_row1_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_def19_row2_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_def19_row3_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_def19_row4_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_def19_row5_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_def19_row6_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_def19_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_def19_row8_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_def19_row9_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_def19_row10_col0, #T_def19_row17_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_def19_row11_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# ...

# %%
# Variance and Performance
X = np.concatenate((pfdf[variances.index.values.tolist()].values.T, pfdf[variances.index.values.tolist()].values.T**2, np.ones_like(variances.values)), axis=-1)
y = variances.values
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                   0.03968
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.961
# Time:                        14:35:34   Log-Likelihood:                -258.78
# No. Observations:                  64   AIC:                             523.6
# Df Residuals:                      61   BIC:                             530.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6583      3.880      0.170      0.866      -7.099       8.416
# ...

# %%
# Variance and Did Upset
X = np.concatenate((dpdf[variances.index.values.tolist()].values.T, np.ones_like(variances.values)), axis=-1)
y = variances.values
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.09107
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.764
# Time:                        15:08:59   Log-Likelihood:                -258.78
# No. Observations:                  64   AIC:                             521.6
# Df Residuals:                      62   BIC:                             525.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8220      2.724      0.302      0.764      -4.623       6.267
# ...

# %%
# Variance and Was Upset
X = np.concatenate((updf[variances.index.values.tolist()].values.T, np.ones_like(variances.values)), axis=-1)
y = variances.values
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.7598
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.387
# Time:                        15:08:34   Log-Likelihood:                -258.43
# No. Observations:                  64   AIC:                             520.9
# Df Residuals:                      62   BIC:                             525.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -3.3251      3.815     -0.872      0.387     -10.951       4.300
# ...

# %%
# Average seed as indicator of performance
X = np.concatenate((df.mean().values.T[:, None], np.ones_like(df.mean().values.T[:, None])), axis=-1)
y = pfdf[variances.index.values.tolist()].values.T
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                  0.008504
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.927
# Time:                        15:08:42   Log-Likelihood:                -112.34
# No. Observations:                  64   AIC:                             228.7
# Df Residuals:                      62   BIC:                             233.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0162      0.176     -0.092      0.927      -0.368       0.336
# ...

# %%
# Variance and Average Seed
X = np.concatenate((df.mean()[variances.index.values.tolist()].values.T[:, None], np.ones_like(variances.values)), axis=-1)
y = variances.values
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.1049
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.747
# Time:                        14:37:30   Log-Likelihood:                -258.77
# No. Observations:                  64   AIC:                             521.5
# Df Residuals:                      62   BIC:                             525.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.5619      1.735     -0.324      0.747      -4.029       2.906
# ...

# %%
# Average seed as indicator of upset
X = np.concatenate((df.skew().values.T[:, None], np.ones_like(df.mean().values.T[:, None])), axis=-1)
y = dpdf[variances.index.values.tolist()].values.T
m = sm.OLS(y, X)
print(m.fit().summary())
plt.scatter(X[:, 0], y)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.06093
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):              0.806
# Time:                        15:10:41   Log-Likelihood:                -62.546
# No. Observations:                  64   AIC:                             129.1
# Df Residuals:                      62   BIC:                             133.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2581      1.046     -0.247      0.806      -2.348       1.832
# ...
